# %%
import json
from collections import OrderedDict
import re

# %%
metadata_path = '/Volumes/comp_micro/rawdata/hummingbird/Cameron/20200924_NewKazanzkyTest/20200925_Diff_Spoke/New_scheme_recalibrate_rename/Images/Pos0/metadata.txt'
path_test = '/Users/cameron.foltz/Documents/metadata.txt'
path_stack = '/Users/cameron.foltz/Documents/metadata_2_MMStack_Default_metadata.txt'
with open(path_stack, 'r') as f:
    stack = json.load(f)
    
with open(path_test, 'r') as f:
    ind = json.load(f)

# %%
key_list = list(stack.keys())

# %%
a_string = stack[key_list[1]]['ROI']
a_string.split('-')[3]
# Out:
# '2048'

# %%
a_string.split('-')
# Out:
# ['0', '0', '2048', '2048']

# %%
stack
# Out:
# {'Summary': {'Prefix': 'metadata_2',
#   'UserName': 'labelfree',
#   'ProfileName': 'Default User',
#   'MicroManagerVersion': '2.0.0-gamma1 20200921',
#   'ComputerName': 'CZLASX-01',
#   'Directory': 'E:\\Cameron\\Test\\test_meta_2',
#   'ChannelGroup': 'Channel',
#   'ChNames': ['State0', 'State1', 'State2', 'State3'],
#   'z-step_um': 0.0,
#   'Interval_ms': 1.0,
#   'CustomIntervals_ms': [],
#   'AxisOrder': ['channel', 'z', 'position', 'time'],
#   'TimeFirst': True,
#   'SlicesFirst': True,
#   'IntendedDimensions': {'time': 1, 'position': 1, 'z': 1, 'channel': 4},
#   'Frames': 1,
#   'Positions': 1,
#   'Slices': 1,
#   'Channels': 4,
#   'StartTime': '2020-09-25 15:49:31.216 -0700',
#   'StagePositions': [],
#   'KeepShutterOpenSlices': False,
#   'KeepShutterOpenChannels': False,
#   'PixelType': 'GRAY16',
#   'Width': 0,
#   'Height': 0,
#   'UserData': {'CameraTimeout': {'type': 'STRING', 'scalar': '20000'},
#    'Depth': {'type': 'STRING', 'scalar': '2'}}},
# ...
