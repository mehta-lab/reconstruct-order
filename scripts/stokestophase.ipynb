# %%
import os
import numpy as np
import glob
import re
import cv2  
import matplotlib.pyplot as plt

# %%
dirpath= r'/Volumes/MicroscopyData/ComputationalMicroscopy/Processed/virtualstaining/u2os_leonetti/2018_09_28_U2OS_rainbow/SMS_2018_0928_1706_1_3_BG_2018_0928_1641_1/'
s0=cv2.imread(r'smb://Flexo/MicroscopyData/ComputationalMicroscopy/Processed/virtualstaining/u2os_leonetti/2018_09_28_U2OS_rainbow/SMS_2018_0928_1706_1_3_BG_2018_0928_1641_1/img_s1_sm_t000_p000_z008.tif')
s1=cv2.imread(os.path.join(dirpath, 'img_s1_sm_t000_p000_z008.tif'))
s2=cv2.imread(os.path.join(dirpath, 'img_s2_sm_t000_p000_z008.tif'))
s3=cv2.imread(os.path.join(dirpath, 'img_s3_sm_t000_p000_z008.tif'))
s1

# %%
os.path.join(dirpath, 'img_s0_sm_t000_p000_z008.tif')
# Out:
# '/Volumes/MicroscopyData/ComputationalMicroscopy/Processed/virtualstaining/u2os_leonetti/2018_09_28_U2OS_rainbow/SMS_2018_0928_1706_1_3_BG_2018_0928_1641_1/img_s0_sm_t000_p000_z008.tif'

# %%
os.chdir(dirpath)

# %%
os.listdir(dirpath)
# Out:
# ['Transmission+Retardance+Orientation_t000_p000_z000.png',
#  'metadata.txt',
#  'img_Transmission_t000_p000_z000.tif',
#  'img_Retardance_t000_p000_z000.tif',
#  'img_Orientation_t000_p000_z000.tif',
#  'img_Scattering_t000_p000_z000.tif',
#  'img_Retardance+Orientation_t000_p000_z000.tif',
#  'img_Scattering+Orientation_t000_p000_z000.tif',
#  'stokes_sm_t000_p000_z000.png',
#  'stokes_bg_t000_p000_z000.png',
#  'img_s0_sm_t000_p000_z000.tif',
#  'img_s1_sm_t000_p000_z000.tif',
#  'img_s2_sm_t000_p000_z000.tif',
#  'img_s3_sm_t000_p000_z000.tif',
#  'img_s0_bg_t000_p000_z000.tif',
#  'img_s1_bg_t000_p000_z000.tif',
#  'img_s2_bg_t000_p000_z000.tif',
#  'img_s3_bg_t000_p000_z000.tif',
#  'Transmission+Retardance+Orientation_t000_p000_z001.png',
#  'img_Transmission_t000_p000_z001.tif',
#  'img_Retardance_t000_p000_z001.tif',
#  'img_Orientation_t000_p000_z001.tif',
#  'img_Scattering_t000_p000_z001.tif',
#  'img_Retardance+Orientation_t000_p000_z001.tif',
# ...
